# %%
import pandas as pd

# Define the path to the CSV file
csv_file_path = './datos_demograficos_LLM.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
#     año  entidad                   indicador                    subcategoría  \
# 0  2018     Achí  Población total de hombres  Población desagregada por sexo
# 1  2018     Achí  Población total de mujeres  Población desagregada por sexo
# 2  2018   Ayapel  Población total de hombres  Población desagregada por sexo
# 3  2018   Ayapel  Población total de mujeres  Población desagregada por sexo
# 4  2018  Caimito  Población total de hombres  Población desagregada por sexo
#
#   unidad de medida  dato_numerico_num
# 0          Hombres              12816
# 1          Mujeres              11536
# 2          Hombres              23900
# 3          Mujeres              23068
# 4          Hombres               7942

# %%
df.columns
# Out:
# Index(['año', 'entidad', 'indicador', 'subcategoría', 'unidad de medida',
#        'dato_numerico_num'],
#       dtype='object')

# %%
df[df['entidad'] == 'Sucre'].head(10)
# Out:
#      año entidad                   indicador                    subcategoría  \
# 20  2018   Sucre  Población total de hombres  Población desagregada por sexo
# 21  2018   Sucre  Población total de hombres  Población desagregada por sexo
# 22  2018   Sucre  Población total de mujeres  Población desagregada por sexo
# 23  2018   Sucre  Población total de mujeres  Población desagregada por sexo
# 44  2019   Sucre  Población total de hombres  Población desagregada por sexo
# 45  2019   Sucre  Población total de hombres  Población desagregada por sexo
# 46  2019   Sucre  Población total de mujeres  Población desagregada por sexo
# 47  2019   Sucre  Población total de mujeres  Población desagregada por sexo
# 68  2020   Sucre  Población total de hombres  Población desagregada por sexo
# 69  2020   Sucre  Población total de hombres  Población desagregada por sexo
#
#    unidad de medida  dato_numerico_num
# 20          Hombres              15914
# 21          Hombres             454988
# ...

# %%
df.sort_values(by=['año', 'entidad', 'indicador', 'subcategoría', 'unidad de medida', 'dato_numerico_num'], inplace=True)
df.drop_duplicates(subset=['año', 'entidad', 'indicador', 'subcategoría', 'unidad de medida'], keep='first', inplace=True)
df[df['entidad'] == 'Sucre'].head(5)
# Out:
#      año entidad                   indicador                    subcategoría  \
# 20  2018   Sucre  Población total de hombres  Población desagregada por sexo
# 22  2018   Sucre  Población total de mujeres  Población desagregada por sexo
# 44  2019   Sucre  Población total de hombres  Población desagregada por sexo
# 46  2019   Sucre  Población total de mujeres  Población desagregada por sexo
# 68  2020   Sucre  Población total de hombres  Población desagregada por sexo
#
#    unidad de medida  dato_numerico_num
# 20          Hombres              15914
# 22          Mujeres              13638
# 44          Hombres              16269
# 46          Mujeres              13984
# 68          Hombres              16718

# %%
df.shape
# Out:
# (176, 6)
